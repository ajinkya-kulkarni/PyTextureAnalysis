# %%
import numpy as np

# %%
arr = np.random.random((4, 4, 3, 3))

# %%
arr
# Out:
# array([[[[0.52659841, 0.82017209, 0.87781894],
#          [0.50112347, 0.29508532, 0.25412339],
#          [0.296474  , 0.01981924, 0.52490235]],
#
#         [[0.49496211, 0.10932502, 0.8591485 ],
#          [0.10639849, 0.06407205, 0.91774671],
#          [0.96603455, 0.43803949, 0.95301514]],
#
#         [[0.45933634, 0.16654684, 0.42808934],
#          [0.57029591, 0.02515139, 0.2622812 ],
#          [0.31054389, 0.27539427, 0.02397524]],
#
#         [[0.38415801, 0.31418476, 0.88100727],
#          [0.84951508, 0.85546532, 0.79887683],
#          [0.2534191 , 0.89365263, 0.5283225 ]]],
#
#
#        [[[0.86769291, 0.14700663, 0.41770699],
#          [0.58123413, 0.81382492, 0.29593215],
#          [0.93591121, 0.9788991 , 0.49298413]],
#
#         [[0.40646447, 0.75420453, 0.79742034],
#          [0.68549878, 0.89266764, 0.24983325],
#          [0.82312647, 0.58429991, 0.89126115]],
#
#         [[0.44774429, 0.49001833, 0.32592983],
# ...

# %%
arr[2, 3]
# Out:
# array([[0.29445149, 0.57334315, 0.18781252],
#        [0.66694391, 0.5358672 , 0.1268453 ],
#        [0.61797951, 0.64950812, 0.06579625]])

# %%
eigenValues, eigenVectors = np.linalg.eigh(arr)

# %%
eigenValues[2, 3]
# Out:
# array([-0.4646749 , -0.25060845,  1.61139829])

# %%
eigenVectors[2, 3]
# Out:
# array([[ 0.4950102 , -0.65883774, -0.56647836],
#        [ 0.21631865,  0.72487648, -0.65403389],
#        [-0.84152905, -0.20121361, -0.50134014]])

# %%
eigenVectors[2, 3][:, 0]
# Out:
# array([ 0.4950102 ,  0.21631865, -0.84152905])

# %%
eigenValues[2, 3][0]
# Out:
# -0.46467489951479735
